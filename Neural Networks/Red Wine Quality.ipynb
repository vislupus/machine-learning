# %% [markdown]
# <a href="https://colab.research.google.com/github/vislupus/machine-learning/blob/master/Red_Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

print(f'Tensorflow version: {tf.__version__}')
# Out:
# Tensorflow version: 2.2.0

# %%
wine_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/winequality-red.csv', parse_dates=True, encoding = "cp1252")
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
wine_data.groupby('quality').count().reset_index()
# Out:
#    quality  fixed acidity  volatile acidity  ...   pH  sulphates  alcohol
# 0        3             10                10  ...   10         10       10
# 1        4             53                53  ...   53         53       53
# 2        5            681               681  ...  681        681      681
# 3        6            638               638  ...  638        638      638
# 4        7            199               199  ...  199        199      199
# 5        8             18                18  ...   18         18       18
#
# [6 rows x 12 columns]

# %%
wine_data['quality'].replace(to_replace={3: 0, 4: 1, 5: 2, 6: 3, 7: 4, 8: 5}, inplace=True)

# %%
X = wine_data[['fixed acidity',
               'volatile acidity',
               'citric acid',
               'residual sugar',
               'chlorides',
               'free sulfur dioxide',
               'total sulfur dioxide',
               'density',
               'pH',
               'sulphates',
               'alcohol']]

y = wine_data['quality']

# %%
corr = wine_data.corr(method = "pearson")
# corr = wine_data.corr(method = "spearman")
# corr = wine_data.corr(method = "kendall")

f, ax = plt.subplots(figsize=(10, 10))

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax, annot=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape[1])
print(y.unique())
# Out:
# 11
# [2 3 4 1 5 0]

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(units=35, input_shape=(X_train.shape[1],), activation='relu'),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dense(units=72, activation='relu'),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dense(units=42, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dense(units=52, activation='relu'),
  tf.keras.layers.Dense(units=6, activation='softmax')
])

model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_881 (Dense)            (None, 35)                420
# _________________________________________________________________
# dense_882 (Dense)            (None, 52)                1872
# _________________________________________________________________
# dense_883 (Dense)            (None, 72)                3816
# _________________________________________________________________
# dense_884 (Dense)            (None, 52)                3796
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 52)                0
# _________________________________________________________________
# dense_885 (Dense)            (None, 52)                2756
# _________________________________________________________________
# dense_886 (Dense)            (None, 42)                2226
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 42)                0
# _________________________________________________________________
# dense_887 (Dense)            (None, 52)                2236
# _________________________________________________________________
# dense_888 (Dense)            (None, 52)                2756
# _________________________________________________________________
# dense_889 (Dense)            (None, 52)                2756
# _________________________________________________________________
# dense_890 (Dense)            (None, 6)                 318
# =================================================================
# Total params: 22,952
# Trainable params: 22,952
# Non-trainable params: 0
# _________________________________________________________________

# %%
cl = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 0s 5ms/step - loss: 1.7346 - accuracy: 0.4097 - val_loss: 1.6702 - val_accuracy: 0.4219
# Epoch 2/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.6256 - accuracy: 0.4269 - val_loss: 1.5580 - val_accuracy: 0.4219
# Epoch 3/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.5236 - accuracy: 0.4269 - val_loss: 1.4490 - val_accuracy: 0.4219
# Epoch 4/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.4314 - accuracy: 0.4269 - val_loss: 1.3476 - val_accuracy: 0.4219
# Epoch 5/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.3439 - accuracy: 0.4269 - val_loss: 1.2614 - val_accuracy: 0.4219
# Epoch 6/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.2847 - accuracy: 0.4277 - val_loss: 1.2026 - val_accuracy: 0.4219
# Epoch 7/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.2427 - accuracy: 0.4285 - val_loss: 1.1701 - val_accuracy: 0.4219
# Epoch 8/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2249 - accuracy: 0.4355 - val_loss: 1.1564 - val_accuracy: 0.4219
# Epoch 9/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2157 - accuracy: 0.4269 - val_loss: 1.1493 - val_accuracy: 0.4219
# Epoch 10/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2041 - accuracy: 0.4418 - val_loss: 1.1466 - val_accuracy: 0.5375
# Epoch 11/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2052 - accuracy: 0.4511 - val_loss: 1.1427 - val_accuracy: 0.4219
# Epoch 12/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1996 - accuracy: 0.4464 - val_loss: 1.1397 - val_accuracy: 0.4969
# Epoch 13/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1962 - accuracy: 0.4488 - val_loss: 1.1337 - val_accuracy: 0.4219
# Epoch 14/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1835 - accuracy: 0.4636 - val_loss: 1.1308 - val_accuracy: 0.4281
# Epoch 15/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1841 - accuracy: 0.4504 - val_loss: 1.1223 - val_accuracy: 0.5312
# Epoch 16/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1735 - accuracy: 0.4957 - val_loss: 1.1156 - val_accuracy: 0.5281
# Epoch 17/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1575 - accuracy: 0.4949 - val_loss: 1.0993 - val_accuracy: 0.5844
# Epoch 18/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1541 - accuracy: 0.5012 - val_loss: 1.0856 - val_accuracy: 0.5688
# Epoch 19/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1460 - accuracy: 0.5160 - val_loss: 1.0741 - val_accuracy: 0.5656
# Epoch 20/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.1272 - accuracy: 0.5324 - val_loss: 1.0570 - val_accuracy: 0.5844
# Epoch 21/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1123 - accuracy: 0.5254 - val_loss: 1.0406 - val_accuracy: 0.5625
# Epoch 22/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0989 - accuracy: 0.5379 - val_loss: 1.0263 - val_accuracy: 0.5844
# Epoch 23/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0670 - accuracy: 0.5575 - val_loss: 1.0175 - val_accuracy: 0.6000
# Epoch 24/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0576 - accuracy: 0.5637 - val_loss: 0.9962 - val_accuracy: 0.5906
# Epoch 25/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0511 - accuracy: 0.5543 - val_loss: 0.9895 - val_accuracy: 0.5844
# Epoch 26/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0358 - accuracy: 0.5637 - val_loss: 0.9893 - val_accuracy: 0.6094
# Epoch 27/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0312 - accuracy: 0.5614 - val_loss: 0.9913 - val_accuracy: 0.6187
# Epoch 28/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0274 - accuracy: 0.5676 - val_loss: 0.9834 - val_accuracy: 0.6156
# Epoch 29/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0189 - accuracy: 0.5700 - val_loss: 0.9810 - val_accuracy: 0.5906
# Epoch 30/50
# 40/40 [==============================] - 0s 3ms/step - loss: 1.0086 - accuracy: 0.5872 - val_loss: 0.9832 - val_accuracy: 0.6062
# Epoch 31/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0051 - accuracy: 0.5754 - val_loss: 0.9888 - val_accuracy: 0.6125
# Epoch 32/50
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0004 - accuracy: 0.5817 - val_loss: 0.9745 - val_accuracy: 0.6000
# Epoch 33/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9928 - accuracy: 0.5825 - val_loss: 0.9731 - val_accuracy: 0.6250
# Epoch 34/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9998 - accuracy: 0.5903 - val_loss: 0.9645 - val_accuracy: 0.6094
# Epoch 35/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9907 - accuracy: 0.5770 - val_loss: 0.9645 - val_accuracy: 0.6125
# Epoch 36/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9856 - accuracy: 0.5903 - val_loss: 0.9602 - val_accuracy: 0.6125
# Epoch 37/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9994 - accuracy: 0.5715 - val_loss: 0.9683 - val_accuracy: 0.6219
# Epoch 38/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9947 - accuracy: 0.5817 - val_loss: 0.9665 - val_accuracy: 0.6062
# Epoch 39/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9749 - accuracy: 0.5817 - val_loss: 0.9654 - val_accuracy: 0.6062
# Epoch 40/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9712 - accuracy: 0.5958 - val_loss: 0.9612 - val_accuracy: 0.6219
# Epoch 41/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9787 - accuracy: 0.5942 - val_loss: 0.9523 - val_accuracy: 0.6187
# Epoch 42/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9744 - accuracy: 0.5887 - val_loss: 0.9531 - val_accuracy: 0.6281
# Epoch 43/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9639 - accuracy: 0.6044 - val_loss: 0.9528 - val_accuracy: 0.6094
# Epoch 44/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9568 - accuracy: 0.5989 - val_loss: 0.9444 - val_accuracy: 0.6156
# Epoch 45/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9576 - accuracy: 0.5997 - val_loss: 0.9466 - val_accuracy: 0.5906
# Epoch 46/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9636 - accuracy: 0.6044 - val_loss: 0.9560 - val_accuracy: 0.6125
# Epoch 47/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9466 - accuracy: 0.6138 - val_loss: 0.9405 - val_accuracy: 0.6187
# Epoch 48/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9516 - accuracy: 0.5872 - val_loss: 0.9376 - val_accuracy: 0.6187
# Epoch 49/50
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9547 - accuracy: 0.5973 - val_loss: 0.9485 - val_accuracy: 0.6219
# Epoch 50/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9426 - accuracy: 0.6005 - val_loss: 0.9438 - val_accuracy: 0.6156

# %%
fig, ax = plt.subplots(figsize=(25,8))

plt.plot(cl.history['accuracy'], label='accuracy')
plt.plot(cl.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.plot(cl.history['loss'], label='loss')
plt.plot(cl.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()

# %%
y_pred = model.predict(X_test)
y_test_list=list(y_test)
total=len(y_test_list)
correct=0

# for i in range(10):
#   print(f'{i+1} - {y_pred[4][i]:.3f} - {y_test_list[4]}')

for i in range(total):
  # print(f'{np.argmax(y_pred[i])} - {np.amax(y_pred[i])} - {y_test_list[i]}')
  if(np.argmax(y_pred[i])==y_test_list[i]):
    correct+=1
print(f'{correct}/{total}')
print(correct/total)
# Out:
# 197/320
# 0.615625

# %%
p_test = model.predict(X_test).argmax(axis=1)
cm = tf.math.confusion_matrix(y_test, p_test)

f, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(cm, annot=True, cmap='Blues', square=True, linewidths=0.01, linecolor='grey')
plt.title('Confustion matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 24.0, 'Predicted label')
